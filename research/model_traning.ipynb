# %%
from xgboost import XGBClassifier
import pandas as pd

# %%
test_df=pd.read_csv("../src/dataset/preprocessed_test_data.csv")
train_df=pd.read_csv("../src/dataset/preprocessed_train_data.csv")

# %%
X_train=train_df.drop(columns=["Target"])
y_train=train_df["Target"]
X_test=test_df.drop(columns=["Target"])
y_test=test_df["Target"]

# %%
X_train.head()
# Out:
#         Age  ...  Recent Major Life Event_Yes
# 0  0.050138  ...                          1.0
# 1  0.501619  ...                          0.0
# 2  0.576866  ...                          1.0
# 3  0.652113  ...                          0.0
# 4  0.275878  ...                          0.0
#
# [5 rows x 37 columns]

# %%
X_test.head()
# Out:
#         Age  ...  Recent Major Life Event_Yes
# 0 -0.098206  ...                          0.0
# 1 -0.248529  ...                          1.0
# 2 -1.526277  ...                          0.0
# 3  1.254704  ...                          1.0
# 4  1.705674  ...                          1.0
#
# [5 rows x 37 columns]

# %%
model = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')

model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=2,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
import pickle
import os

# %%
file_name="xgb_clf.pkl"
folder_path = "../src/models"  
file_path=os.path.join(folder_path,file_name)

os.makedirs(folder_path,exist_ok=True)

with open(file_path,"wb") as f:
    pickle.dump(model,f)

print("Model saved at ",file_path)
# Out:
# Model saved at  ../src/models\xgb_clf.pkl

# %%
print(file_path)
# Out:
# ../src/models\xgb_clf.pkl
